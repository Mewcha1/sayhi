# %% [markdown]
# ### Current

# %% [markdown]
# ##### C1B00S0: Current climate that assumes no future change in in-land vertical boundary recharge and no sea level rise

# %% [markdown]
# ![current](C1B00S0/Model2021To2070TS10M1B00S0C1L1WDC.png)

# %% [markdown]
# ![Current](C1B00S0/Model2021To2070TS10M1B00S0C1L2WDC.png)

# %% [markdown]
# ![](C1B00S0/Model2021To2070TS10M1B00S0C1L7WDC.png)

# %% [markdown]
# ##### C2B00S0: Future climate static method that assumes no future change in in-land vertical boundary recharge and no sea level rise

# %% [markdown]
# ![C2B00S0/Model2021To2070TS10M1B00S0C2L1WDC.png](C2B00S0/Model2021To2070TS10M1B00S0C2L1WDC.png)

# %% [markdown]
# ![Current](C2B00S0/Model2021To2070TS10M1B00S0C2L7WDC.png)

# %% [markdown]
# ##### C2B11S0: Future climate static method that uses a machine learning method with no sea level rise

# %% [markdown]
# ![C2B11S0/Model2021To2070TS10M1B11S0C2L1WDC.png](C2B11S0/Model2021To2070TS10M1B11S0C2L1WDC.png)

# %% [markdown]
# ![C2B11S0/Model2021To2070TS10M1B11S0C2L2WDC.png](C2B11S0/Model2021To2070TS10M1B11S0C2L2WDC.png)

# %% [markdown]
# ![C2B11S0/Model2021To2070TS10M1B11S0C2L7WDC.png](C2B11S0/Model2021To2070TS10M1B11S0C2L7WDC.png)

# %% [markdown]
# ##### C2B11S1: Future climate static method that uses a machine learning method with sea level rise

# %% [markdown]
# ![C2B11S1/Model2021To2070TS10M1B11S1C2L1WDC.png](C2B11S1/Model2021To2070TS10M1B11S1C2L1WDC.png)

# %% [markdown]
# ![C2B11S1/Model2021To2070TS10M1B11S1C2L2WDC.png](C2B11S1/Model2021To2070TS10M1B11S1C2L2WDC.png)

# %% [markdown]
# ![C2B11S1/Model2021To2070TS10M1B11S1C2L7WDC.png](C2B11S1/Model2021To2070TS10M1B11S1C2L7WDC.png)

# %% [markdown]
# ##### M2M3: Simulation Optimization (Waimalu314v0 and Waimalu314v2)

# %% [markdown]
# ![M2M3/Model2021To2070TS10M2B00S0C1L1WDC.png](M2M3/Model2021To2070TS10M2B00S0C1L1WDC.png)

# %% [markdown]
# ![M2M3/Model2021To2070TS10M2B00S0C2L1WDC.png](M2M3/Model2021To2070TS10M2B00S0C2L1WDC.png)

# %% [markdown]
# ![Model2021To2070TS10M2B11S1C2L7WDC.png](attachment:d0ee9f1a-65bc-40bd-ad0c-dce8d3c81241.png)

# %% [markdown]
# ![M2M3/Model2021To2070TS10M3B00S0C1L1WDC.png](M2M3/Model2021To2070TS10M3B00S0C1L1WDC.png)

# %% [markdown]
# ![M2M3/Model2021To2070TS10M3B00S0C2L1WDC.png](M2M3/Model2021To2070TS10M3B00S0C2L1WDC.png)

# %% [markdown]
# ![M2M3/Model2021To2070TS10M3B11S1C2L7WDC.png](M2M3/Model2021To2070TS10M3B11S1C2L7WDC.png)

# %% [markdown]
# ##### S0: No sea level rise

# %% [markdown]
# ![S0/Model2021To2070TS10M1B11S0C1L1WDC.png](S0/Model2021To2070TS10M1B11S0C1L1WDC.png)

# %% [markdown]
# ![S0/Model2021To2070TS10M1B11S0C1L7WDC.png](S0/Model2021To2070TS10M1B11S0C1L7WDC.png)

# %% [markdown]
# ##### S0: Sea level rise

# %% [markdown]
# ![S1/Model2021To2070TS10M1B00S1C1L1WDC.png](S1/Model2021To2070TS10M1B00S1C1L1WDC.png)

# %% [markdown]
# ![S1/Model2021To2070TS10M1B00S1C2L1WDC.png](S1/Model2021To2070TS10M1B00S1C2L1WDC.png)

# %% [markdown]
# ![S1/Model2021To2070TS10M1B00S1C2L2WDC.png](S1/Model2021To2070TS10M1B00S1C2L2WDC.png)

# %% [markdown]
# ![S1/Model2021To2070TS10M1B00S1C2L7WDC.png](S1/Model2021To2070TS10M1B00S1C2L7WDC.png)

# %% [markdown]
# ![S1/Model2021To2070TS10M1B11S1C1L1WDC.png](S1/Model2021To2070TS10M1B11S1C1L1WDC.png)
