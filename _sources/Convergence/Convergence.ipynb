# %% [markdown]
# ### Convergence

# %% [markdown]
# ![Conv.png](Conv.png)

# %% [markdown]
# ![DVConv.png](DVConv.png)

# %% [markdown]
# ![Fig1M1B00S0C1L1H1V5111F21D10P000G0R1I90.png](Fig1M1B00S0C1L1H1V5111F21D10P000G0R1I90.png)
